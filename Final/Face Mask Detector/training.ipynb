# %%
import numpy as np
#load data
data=np.load('data.npy')
target=np.load('target.npy')

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint

model=Sequential()

#1st conv
model.add(Conv2D(200,(3,3),input_shape=data.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

#2nd conv
model.add(Conv2D(100,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(50,activation='relu'))

model.add(Dense(2,activation='softmax')) #final layer for two categories
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
from sklearn.model_selection import train_test_split
train_data,test_data,train_target,test_target=train_test_split(data,target,test_size=0.1)

# %%
checkpoint = ModelCheckpoint('model-{epoch:03d}.model',monitor='val_loss',verbose=0,save_best_only=True,mode='auto')
history=model.fit(train_data,train_target,epochs=20,callbacks=[checkpoint],validation_split=0.2)
# Out:
# Epoch 1/20
# 31/31 [==============================] - ETA: 0s - loss: 0.7191 - accuracy: 0.5424
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model-001.model\assets
# INFO:tensorflow:Assets written to: model-001.model\assets
# 31/31 [==============================] - 42s 1s/step - loss: 0.7191 - accuracy: 0.5424 - val_loss: 0.6370 - val_accuracy: 0.7218
# Epoch 2/20
# 31/31 [==============================] - ETA: 0s - loss: 0.5438 - accuracy: 0.7071
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model-002.model\assets
# INFO:tensorflow:Assets written to: model-002.model\assets
# 31/31 [==============================] - 45s 1s/step - loss: 0.5438 - accuracy: 0.7071 - val_loss: 0.5093 - val_accuracy: 0.7419
# Epoch 3/20
# 31/31 [==============================] - ETA: 0s - loss: 0.3689 - accuracy: 0.8424
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model-003.model\assets
# INFO:tensorflow:Assets written to: model-003.model\assets
# 31/31 [==============================] - 47s 2s/step - loss: 0.3689 - accuracy: 0.8424 - val_loss: 0.3300 - val_accuracy: 0.8790
# Epoch 4/20
# 31/31 [==============================] - ETA: 0s - loss: 0.2333 - accuracy: 0.9131
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model-004.model\assets
# INFO:tensorflow:Assets written to: model-004.model\assets
# 31/31 [==============================] - 49s 2s/step - loss: 0.2333 - accuracy: 0.9131 - val_loss: 0.2686 - val_accuracy: 0.8911
# Epoch 5/20
# 31/31 [==============================] - 44s 1s/step - loss: 0.1507 - accuracy: 0.9485 - val_loss: 0.3141 - val_accuracy: 0.8831
# Epoch 6/20
# 31/31 [==============================] - ETA: 0s - loss: 0.1183 - accuracy: 0.9495
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model-006.model\assets
# INFO:tensorflow:Assets written to: model-006.model\assets
# 31/31 [==============================] - 43s 1s/step - loss: 0.1183 - accuracy: 0.9495 - val_loss: 0.1983 - val_accuracy: 0.9435
# Epoch 7/20
# 31/31 [==============================] - 45s 1s/step - loss: 0.1122 - accuracy: 0.9586 - val_loss: 0.3332 - val_accuracy: 0.8992
# Epoch 8/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9717
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model-008.model\assets
# INFO:tensorflow:Assets written to: model-008.model\assets
# 31/31 [==============================] - 41s 1s/step - loss: 0.0779 - accuracy: 0.9717 - val_loss: 0.1867 - val_accuracy: 0.9315
# Epoch 9/20
# 31/31 [==============================] - 43s 1s/step - loss: 0.1045 - accuracy: 0.9535 - val_loss: 0.2523 - val_accuracy: 0.9234
# Epoch 10/20
# 31/31 [==============================] - 42s 1s/step - loss: 0.0653 - accuracy: 0.9788 - val_loss: 0.2096 - val_accuracy: 0.9435
# Epoch 11/20
# 31/31 [==============================] - 51s 2s/step - loss: 0.0529 - accuracy: 0.9828 - val_loss: 0.2188 - val_accuracy: 0.9194
# Epoch 12/20
# 31/31 [==============================] - 43s 1s/step - loss: 0.0368 - accuracy: 0.9889 - val_loss: 0.3583 - val_accuracy: 0.9113
# Epoch 13/20
# 31/31 [==============================] - 38s 1s/step - loss: 0.0231 - accuracy: 0.9939 - val_loss: 0.2347 - val_accuracy: 0.9194
# Epoch 14/20
# 31/31 [==============================] - 44s 1s/step - loss: 0.0183 - accuracy: 0.9919 - val_loss: 0.2167 - val_accuracy: 0.9315
# Epoch 15/20
# 31/31 [==============================] - 47s 2s/step - loss: 0.0440 - accuracy: 0.9838 - val_loss: 0.1910 - val_accuracy: 0.9395
# Epoch 16/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9879
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model-016.model\assets
# INFO:tensorflow:Assets written to: model-016.model\assets
# 31/31 [==============================] - 49s 2s/step - loss: 0.0339 - accuracy: 0.9879 - val_loss: 0.1803 - val_accuracy: 0.9355
# Epoch 17/20
# 31/31 [==============================] - 50s 2s/step - loss: 0.0195 - accuracy: 0.9939 - val_loss: 0.2231 - val_accuracy: 0.9355
# Epoch 18/20
# 31/31 [==============================] - 43s 1s/step - loss: 0.0116 - accuracy: 0.9960 - val_loss: 0.1908 - val_accuracy: 0.9476
# Epoch 19/20
# 31/31 [==============================] - 39s 1s/step - loss: 0.0081 - accuracy: 0.9990 - val_loss: 0.4481 - val_accuracy: 0.9113
# Epoch 20/20
# 31/31 [==============================] - 35s 1s/step - loss: 0.0133 - accuracy: 0.9949 - val_loss: 0.2337 - val_accuracy: 0.9395

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['loss'],'g',label='training loss')
plt.plot(history.history['val_loss'],'y',label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'],'g',label='training accuracy')
plt.plot(history.history['val_accuracy'],'y',label='validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
print(model.evaluate(test_data,test_target))
# Out:
# 5/5 [==============================] - 1s 230ms/step - loss: 0.1943 - accuracy: 0.9493
# [0.19429145753383636, 0.9492753744125366]
